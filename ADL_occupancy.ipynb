# %%
from ADLmainloop import ADLmain, ADLmainId
from ADLbasic import ADL
from utilsADL import dataLoader, plotPerformance
import random
import torch
import numpy as np

# %%
# random seed control
np.random.seed(0)
torch.manual_seed(0)
random.seed(0)

# %%
# load data
dataStreams = dataLoader('../dataset/occupancy2.mat', batchSize = 500)
# Out:
# Number of input:  5
# Number of output:  2
# Number of batch:  40

# %%
print('All labeled')
# Out:
# All labeled

# %%
allMetrics = []

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet0, performanceHistory0, allPerformance = ADLmain(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
# 100% (40 of 40) |########################| Elapsed Time: 0:00:30 ETA:  00:00:00
# === Performance result ===
# Accuracy:  85.96410256410257 (+/-) 23.099156241438855
# Testing Loss:  0.38295669148180583 (+/-) 0.5218399034029009
# Precision:  0.8543440703214296
# Recall:  0.8596410256410256
# F1 score:  0.8481404685839019
# Testing Time:  0.00428156363658416 (+/-) 0.007164606931911697
# Training Time:  0.781730572382609 (+/-) 0.1278992100627535
#
#
# === Average network evolution ===
# Total hidden node:  36.0 (+/-) 10.502746893441367
# Number of layer:  1.1794871794871795 (+/-) 0.49983560742610056
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=51, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=51, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 51
# No. of parameters : 410
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory0[0],performanceHistory0[1],performanceHistory0[2],
                performanceHistory0[3],performanceHistory0[4],performanceHistory0[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet1, performanceHistory1, allPerformance = ADLmain(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
# 100% (40 of 40) |########################| Elapsed Time: 0:00:50 ETA:  00:00:00
# === Performance result ===
# Accuracy:  76.37435897435897 (+/-) 31.211837974033045
# Testing Loss:  0.7090662261292052 (+/-) 0.8818734695281962
# Precision:  0.7313057205991592
# Recall:  0.7637435897435897
# F1 score:  0.7383906338943684
# Testing Time:  0.005747073735946264 (+/-) 0.008786587592057528
# Training Time:  1.2762938401637933 (+/-) 0.7157203839075159
#
#
# === Average network evolution ===
# Total hidden node:  35.43589743589744 (+/-) 13.870823227736759
# Number of layer:  3.4358974358974357 (+/-) 1.4640105049866874
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=13, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=13, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 13
# No. of parameters : 106
# basicNet(
#   (linear): Linear(in_features=13, out_features=16, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=16, out_features=2, bias=True)
# )
# No. of inputs : 13
# No. of nodes : 16
# No. of parameters : 258
# basicNet(
#   (linear): Linear(in_features=16, out_features=10, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=10, out_features=2, bias=True)
# )
# No. of inputs : 16
# No. of nodes : 10
# No. of parameters : 192
# basicNet(
#   (linear): Linear(in_features=10, out_features=2, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=2, out_features=2, bias=True)
# )
# No. of inputs : 10
# No. of nodes : 2
# No. of parameters : 28
# basicNet(
#   (linear): Linear(in_features=2, out_features=12, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=12, out_features=2, bias=True)
# )
# No. of inputs : 2
# No. of nodes : 12
# No. of parameters : 62
# Voting weight:  [0.0, 0.000999000999000999, 0.0, 0.0, 0.9990009990009989]

# %%
plotPerformance(performanceHistory1[0],performanceHistory1[1],performanceHistory1[2],
                performanceHistory1[3],performanceHistory1[4],performanceHistory1[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet2, performanceHistory2, allPerformance = ADLmain(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
# 100% (40 of 40) |########################| Elapsed Time: 0:00:52 ETA:  00:00:00
# === Performance result ===
# Accuracy:  71.26666666666667 (+/-) 32.73255521556744
# Testing Loss:  0.7514281841442705 (+/-) 0.905326207544147
# Precision:  0.6436317082795664
# Recall:  0.7126666666666667
# F1 score:  0.6686816506916395
# Testing Time:  0.005685885747273763 (+/-) 0.008311649154699277
# Training Time:  1.3270232004997058 (+/-) 0.6367225194140421
#
#
# === Average network evolution ===
# Total hidden node:  38.82051282051282 (+/-) 17.18507371853185
# Number of layer:  3.641025641025641 (+/-) 1.5605255440720962
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=13, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=13, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 13
# No. of parameters : 106
# basicNet(
#   (linear): Linear(in_features=13, out_features=24, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=24, out_features=2, bias=True)
# )
# No. of inputs : 13
# No. of nodes : 24
# No. of parameters : 386
# basicNet(
#   (linear): Linear(in_features=24, out_features=7, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=7, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 7
# No. of parameters : 191
# basicNet(
#   (linear): Linear(in_features=7, out_features=3, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=3, out_features=2, bias=True)
# )
# No. of inputs : 7
# No. of nodes : 3
# No. of parameters : 32
# basicNet(
#   (linear): Linear(in_features=3, out_features=11, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=11, out_features=2, bias=True)
# )
# No. of inputs : 3
# No. of nodes : 11
# No. of parameters : 68
# basicNet(
#   (linear): Linear(in_features=11, out_features=8, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=8, out_features=2, bias=True)
# )
# No. of inputs : 11
# No. of nodes : 8
# No. of parameters : 114
# Voting weight:  [0.0, 0.3333333333333333, 0.0, 0.0, 0.3333333333333333, 0.3333333333333333]

# %%
plotPerformance(performanceHistory2[0],performanceHistory2[1],performanceHistory2[2],
                performanceHistory2[3],performanceHistory2[4],performanceHistory2[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet3, performanceHistory3, allPerformance = ADLmain(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
# 100% (40 of 40) |########################| Elapsed Time: 0:00:52 ETA:  00:00:00
# === Performance result ===
# Accuracy:  74.76923076923076 (+/-) 30.797054086940285
# Testing Loss:  0.7674165468734617 (+/-) 0.921776708904348
# Precision:  0.7268317412814658
# Recall:  0.7476923076923077
# F1 score:  0.7347538147378807
# Testing Time:  0.007508436838785808 (+/-) 0.011034097604749958
# Training Time:  1.3387909057812812 (+/-) 0.5797149590174672
#
#
# === Average network evolution ===
# Total hidden node:  46.35897435897436 (+/-) 14.758721332090966
# Number of layer:  3.5128205128205128 (+/-) 1.3936080247898657
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=23, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=23, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 23
# No. of parameters : 186
# basicNet(
#   (linear): Linear(in_features=23, out_features=19, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=19, out_features=2, bias=True)
# )
# No. of inputs : 23
# No. of nodes : 19
# No. of parameters : 496
# basicNet(
#   (linear): Linear(in_features=19, out_features=8, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=8, out_features=2, bias=True)
# )
# No. of inputs : 19
# No. of nodes : 8
# No. of parameters : 178
# basicNet(
#   (linear): Linear(in_features=8, out_features=4, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=4, out_features=2, bias=True)
# )
# No. of inputs : 8
# No. of nodes : 4
# No. of parameters : 46
# basicNet(
#   (linear): Linear(in_features=4, out_features=11, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=11, out_features=2, bias=True)
# )
# No. of inputs : 4
# No. of nodes : 11
# No. of parameters : 79
# Voting weight:  [0.0, 0.000999000999000999, 0.0, 0.0, 0.9990009990009989]

# %%
plotPerformance(performanceHistory3[0],performanceHistory3[1],performanceHistory3[2],
                performanceHistory3[3],performanceHistory3[4],performanceHistory3[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet4, performanceHistory4, allPerformance = ADLmain(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
# 100% (40 of 40) |########################| Elapsed Time: 0:00:58 ETA:  00:00:00
# === Performance result ===
# Accuracy:  71.33846153846154 (+/-) 33.094213727606835
# Testing Loss:  0.7473236171719737 (+/-) 0.8504472635093057
# Precision:  0.6441477538461539
# Recall:  0.7133846153846154
# F1 score:  0.6691406628459744
# Testing Time:  0.007741390130458734 (+/-) 0.009375758427705288
# Training Time:  1.4816628358302972 (+/-) 0.6915465270629231
#
#
# === Average network evolution ===
# Total hidden node:  51.256410256410255 (+/-) 21.868743587323436
# Number of layer:  4.487179487179487 (+/-) 1.7375460867792225
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=16, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=16, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 16
# No. of parameters : 130
# basicNet(
#   (linear): Linear(in_features=16, out_features=8, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=8, out_features=2, bias=True)
# )
# No. of inputs : 16
# No. of nodes : 8
# No. of parameters : 154
# basicNet(
#   (linear): Linear(in_features=8, out_features=18, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=18, out_features=2, bias=True)
# )
# No. of inputs : 8
# No. of nodes : 18
# No. of parameters : 200
# basicNet(
#   (linear): Linear(in_features=18, out_features=10, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=10, out_features=2, bias=True)
# )
# No. of inputs : 18
# No. of nodes : 10
# No. of parameters : 212
# basicNet(
#   (linear): Linear(in_features=10, out_features=11, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=11, out_features=2, bias=True)
# )
# No. of inputs : 10
# No. of nodes : 11
# No. of parameters : 145
# basicNet(
#   (linear): Linear(in_features=11, out_features=10, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=10, out_features=2, bias=True)
# )
# No. of inputs : 11
# No. of nodes : 10
# No. of parameters : 142
# basicNet(
#   (linear): Linear(in_features=10, out_features=8, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=8, out_features=2, bias=True)
# )
# No. of inputs : 10
# No. of nodes : 8
# No. of parameters : 106
# Voting weight:  [0.0, 0.25, 0.0, 0.0, 0.25, 0.25, 0.25]

# %%
plotPerformance(performanceHistory4[0],performanceHistory4[1],performanceHistory4[2],
                performanceHistory4[3],performanceHistory4[4],performanceHistory4[5])

# %%
# all results

# 0: accuracy
# 1: f1_score
# 2: precision_score
# 3: recall_score
# 4: training_time
# 5: testingTime
# 6: nHiddenLayer
# 7: nHiddenNode

meanResults = np.round_(np.mean(allMetrics,0), decimals=2)
stdResults  = np.round_(np.std(allMetrics,0), decimals=2)

print('\n')
print('========== Performance creditcarddefault ==========')
print('Preq Accuracy: ', meanResults[0].item(), '(+/-)',stdResults[0].item())
print('F1 score: ', meanResults[1].item(), '(+/-)',stdResults[1].item())
print('Precision: ', meanResults[2].item(), '(+/-)',stdResults[2].item())
print('Recall: ', meanResults[3].item(), '(+/-)',stdResults[3].item())
print('Training time: ', meanResults[4].item(), '(+/-)',stdResults[4].item())
print('Testing time: ', meanResults[5].item(), '(+/-)',stdResults[5].item())

print('\n')
print('========== Network ==========')
print('Number of hidden layers: ', meanResults[6].item(), '(+/-)',stdResults[6].item())
print('Number of features: ', meanResults[7].item(), '(+/-)',stdResults[7].item())
# Out:
# ========== Performance creditcarddefault ==========
# Preq Accuracy:  75.94 (+/-) 5.39
# F1 score:  0.73 (+/-) 0.07
# Precision:  0.72 (+/-) 0.08
# Recall:  0.76 (+/-) 0.05
# Training time:  1.24 (+/-) 0.24
# Testing time:  0.01 (+/-) 0.0
#
#
# ========== Network ==========
# Number of hidden layers:  4.8 (+/-) 2.04
# Number of features:  63.2 (+/-) 10.78

# %% [markdown]
# ### 50% labeled data

# %%
print('50% labeled')
# Out:
# 50% labeled

# %%
allMetrics = []

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet0, performanceHistory0, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.5)
allMetrics.append(allPerformance)
# Out:
# 100% (40 of 40) |########################| Elapsed Time: 0:00:20 ETA:  00:00:00
# === Performance result ===
# Accuracy:  73.18974358974359 (+/-) 33.15814317642972
# Testing Loss:  0.7035583955868601 (+/-) 0.7892125371788252
# Precision:  0.7163021102231992
# Recall:  0.7318974358974359
# F1 score:  0.7230073474540696
# Testing Time:  0.0043865595108423475 (+/-) 0.008075301624493677
# Training Time:  0.5130020227187719 (+/-) 0.042022331999491076
#
#
# === Average network evolution ===
# Total hidden node:  24.53846153846154 (+/-) 6.8532086957868055
# Number of layer:  1.9230769230769231 (+/-) 0.2664693550105965
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=13, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=13, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 13
# No. of parameters : 106
# basicNet(
#   (linear): Linear(in_features=13, out_features=19, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=19, out_features=2, bias=True)
# )
# No. of inputs : 13
# No. of nodes : 19
# No. of parameters : 306
# Voting weight:  [0.0, 1.0]

# %%
plotPerformance(performanceHistory0[0],performanceHistory0[1],performanceHistory0[2],
                performanceHistory0[3],performanceHistory0[4],performanceHistory0[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet1, performanceHistory1, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.5)
allMetrics.append(allPerformance)
# Out:
# 100% (40 of 40) |########################| Elapsed Time: 0:00:20 ETA:  00:00:00
# === Performance result ===
# Accuracy:  65.83076923076923 (+/-) 36.40125493642693
# Testing Loss:  0.8154369719708577 (+/-) 0.9132272482132301
# Precision:  0.6557278790642966
# Recall:  0.6583076923076923
# F1 score:  0.6570046151221115
# Testing Time:  0.0031327712230193308 (+/-) 0.0010482497273441938
# Training Time:  0.5290628885611509 (+/-) 0.07313431085902582
#
#
# === Average network evolution ===
# Total hidden node:  20.615384615384617 (+/-) 7.095015890968578
# Number of layer:  2.051282051282051 (+/-) 0.5037662231894487
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=10, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=10, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 10
# No. of parameters : 82
# basicNet(
#   (linear): Linear(in_features=10, out_features=14, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=14, out_features=2, bias=True)
# )
# No. of inputs : 10
# No. of nodes : 14
# No. of parameters : 184
# basicNet(
#   (linear): Linear(in_features=14, out_features=12, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=12, out_features=2, bias=True)
# )
# No. of inputs : 14
# No. of nodes : 12
# No. of parameters : 206
# basicNet(
#   (linear): Linear(in_features=12, out_features=4, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=4, out_features=2, bias=True)
# )
# No. of inputs : 12
# No. of nodes : 4
# No. of parameters : 62
# Voting weight:  [0.0, 0.25, 0.25, 0.5]

# %%
plotPerformance(performanceHistory1[0],performanceHistory1[1],performanceHistory1[2],
                performanceHistory1[3],performanceHistory1[4],performanceHistory1[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet2, performanceHistory2, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.5)
allMetrics.append(allPerformance)
# Out:
# 100% (40 of 40) |########################| Elapsed Time: 0:00:23 ETA:  00:00:00
# === Performance result ===
# Accuracy:  67.60000000000001 (+/-) 36.4281378987347
# Testing Loss:  0.7558692422910378 (+/-) 0.8587333368408099
# Precision:  0.6526170492543817
# Recall:  0.676
# F1 score:  0.6632058179659335
# Testing Time:  0.0052852691748203375 (+/-) 0.007746003300397223
# Training Time:  0.5946924441900009 (+/-) 0.10950044814471924
#
#
# === Average network evolution ===
# Total hidden node:  29.641025641025642 (+/-) 10.894569758834525
# Number of layer:  2.6666666666666665 (+/-) 0.7623624998624874
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=12, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=12, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 12
# No. of parameters : 98
# basicNet(
#   (linear): Linear(in_features=12, out_features=15, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=15, out_features=2, bias=True)
# )
# No. of inputs : 12
# No. of nodes : 15
# No. of parameters : 227
# basicNet(
#   (linear): Linear(in_features=15, out_features=13, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=13, out_features=2, bias=True)
# )
# No. of inputs : 15
# No. of nodes : 13
# No. of parameters : 236
# basicNet(
#   (linear): Linear(in_features=13, out_features=3, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=3, out_features=2, bias=True)
# )
# No. of inputs : 13
# No. of nodes : 3
# No. of parameters : 50
# Voting weight:  [0.0, 0.000999000999000999, 0.0, 0.9990009990009989]

# %%
plotPerformance(performanceHistory2[0],performanceHistory2[1],performanceHistory2[2],
                performanceHistory2[3],performanceHistory2[4],performanceHistory2[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet3, performanceHistory3, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.5)
allMetrics.append(allPerformance)
# Out:
# 100% (40 of 40) |########################| Elapsed Time: 0:00:25 ETA:  00:00:00
# === Performance result ===
# Accuracy:  67.98461538461538 (+/-) 35.030137489658514
# Testing Loss:  0.8594937653471835 (+/-) 0.9498469774097028
# Precision:  0.6666511079404467
# Recall:  0.6798461538461539
# F1 score:  0.6728440927327023
# Testing Time:  0.00548560802753155 (+/-) 0.007006346780347654
# Training Time:  0.6383218826391758 (+/-) 0.09776148248250156
#
#
# === Average network evolution ===
# Total hidden node:  33.743589743589745 (+/-) 8.874388238122132
# Number of layer:  2.923076923076923 (+/-) 0.6153846153846153
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=15, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=15, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 15
# No. of parameters : 122
# basicNet(
#   (linear): Linear(in_features=15, out_features=9, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=9, out_features=2, bias=True)
# )
# No. of inputs : 15
# No. of nodes : 9
# No. of parameters : 164
# basicNet(
#   (linear): Linear(in_features=9, out_features=17, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=17, out_features=2, bias=True)
# )
# No. of inputs : 9
# No. of nodes : 17
# No. of parameters : 206
# basicNet(
#   (linear): Linear(in_features=17, out_features=3, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=3, out_features=2, bias=True)
# )
# No. of inputs : 17
# No. of nodes : 3
# No. of parameters : 62
# Voting weight:  [0.0, 0.000999000999000999, 0.0, 0.9990009990009989]

# %%
plotPerformance(performanceHistory3[0],performanceHistory3[1],performanceHistory3[2],
                performanceHistory3[3],performanceHistory3[4],performanceHistory3[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet4, performanceHistory4, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.5)
allMetrics.append(allPerformance)
# Out:
# 100% (40 of 40) |########################| Elapsed Time: 0:00:20 ETA:  00:00:00
# === Performance result ===
# Accuracy:  64.35897435897436 (+/-) 36.70266334183335
# Testing Loss:  0.8073597893190498 (+/-) 0.9051990837619814
# Precision:  0.6280150984850124
# Recall:  0.6435897435897436
# F1 score:  0.6354481062255702
# Testing Time:  0.003516331697121645 (+/-) 0.0012332728691343625
# Training Time:  0.5191378654577793 (+/-) 0.0729452124565064
#
#
# === Average network evolution ===
# Total hidden node:  25.53846153846154 (+/-) 6.8905217466334445
# Number of layer:  2.051282051282051 (+/-) 0.5037662231894487
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=13, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=13, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 13
# No. of parameters : 106
# basicNet(
#   (linear): Linear(in_features=13, out_features=17, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=17, out_features=2, bias=True)
# )
# No. of inputs : 13
# No. of nodes : 17
# No. of parameters : 274
# basicNet(
#   (linear): Linear(in_features=17, out_features=9, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=9, out_features=2, bias=True)
# )
# No. of inputs : 17
# No. of nodes : 9
# No. of parameters : 182
# basicNet(
#   (linear): Linear(in_features=9, out_features=3, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=3, out_features=2, bias=True)
# )
# No. of inputs : 9
# No. of nodes : 3
# No. of parameters : 38
# Voting weight:  [0.0, 0.25, 0.25, 0.5]

# %%
plotPerformance(performanceHistory4[0],performanceHistory4[1],performanceHistory4[2],
                performanceHistory4[3],performanceHistory4[4],performanceHistory4[5])

# %%
# all results

# 0: accuracy
# 1: f1_score
# 2: precision_score
# 3: recall_score
# 4: training_time
# 5: testingTime
# 6: nHiddenLayer
# 7: nHiddenNode

meanResults = np.round_(np.mean(allMetrics,0), decimals=2)
stdResults  = np.round_(np.std(allMetrics,0), decimals=2)

print('\n')
print('========== Performance creditcarddefault ==========')
print('Preq Accuracy: ', meanResults[0].item(), '(+/-)',stdResults[0].item())
print('F1 score: ', meanResults[1].item(), '(+/-)',stdResults[1].item())
print('Precision: ', meanResults[2].item(), '(+/-)',stdResults[2].item())
print('Recall: ', meanResults[3].item(), '(+/-)',stdResults[3].item())
print('Training time: ', meanResults[4].item(), '(+/-)',stdResults[4].item())
print('Testing time: ', meanResults[5].item(), '(+/-)',stdResults[5].item())

print('\n')
print('========== Network ==========')
print('Number of hidden layers: ', meanResults[6].item(), '(+/-)',stdResults[6].item())
print('Number of features: ', meanResults[7].item(), '(+/-)',stdResults[7].item())
# Out:
# ========== Performance creditcarddefault ==========
# Preq Accuracy:  67.79 (+/-) 2.99
# F1 score:  0.67 (+/-) 0.03
# Precision:  0.66 (+/-) 0.03
# Recall:  0.68 (+/-) 0.03
# Training time:  0.56 (+/-) 0.05
# Testing time:  0.0 (+/-) 0.0
#
#
# ========== Network ==========
# Number of hidden layers:  3.6 (+/-) 0.8
# Number of features:  40.2 (+/-) 4.31

# %% [markdown]
# ### 25% Labeled Data

# %%
print('25% labeled')
# Out:
# 25% labeled

# %%
allMetrics = []

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet0, performanceHistory0, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.25)
allMetrics.append(allPerformance)
# Out:
# 100% (40 of 40) |########################| Elapsed Time: 0:00:10 ETA:  00:00:00
# === Performance result ===
# Accuracy:  65.10769230769232 (+/-) 36.22142293298182
# Testing Loss:  0.7551558038625771 (+/-) 0.7157746464314612
# Precision:  0.6413070754383366
# Recall:  0.6510769230769231
# F1 score:  0.646029159517903
# Testing Time:  0.00400698490631886 (+/-) 0.007069038956566996
# Training Time:  0.27444970302092725 (+/-) 0.039197840022892554
#
#
# === Average network evolution ===
# Total hidden node:  13.564102564102564 (+/-) 5.143055421284481
# Number of layer:  2.051282051282051 (+/-) 0.5037662231894487
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=5, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=5, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 5
# No. of parameters : 42
# basicNet(
#   (linear): Linear(in_features=5, out_features=12, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=12, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 12
# No. of parameters : 98
# basicNet(
#   (linear): Linear(in_features=12, out_features=6, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=6, out_features=2, bias=True)
# )
# No. of inputs : 12
# No. of nodes : 6
# No. of parameters : 92
# basicNet(
#   (linear): Linear(in_features=6, out_features=2, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=2, out_features=2, bias=True)
# )
# No. of inputs : 6
# No. of nodes : 2
# No. of parameters : 20
# Voting weight:  [0.0, 0.4995004995004996, 0.0004995004995004996, 0.5]

# %%
plotPerformance(performanceHistory0[0],performanceHistory0[1],performanceHistory0[2],
                performanceHistory0[3],performanceHistory0[4],performanceHistory0[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet1, performanceHistory1, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.25)
allMetrics.append(allPerformance)
# Out:
# 100% (40 of 40) |########################| Elapsed Time: 0:00:13 ETA:  00:00:00
# === Performance result ===
# Accuracy:  67.30256410256409 (+/-) 35.19221568340688
# Testing Loss:  0.8224439489392515 (+/-) 0.8261961928447031
# Precision:  0.6498363256066335
# Recall:  0.673025641025641
# F1 score:  0.6603859371865726
# Testing Time:  0.005256866797422752 (+/-) 0.007359651970462146
# Training Time:  0.33447140302413547 (+/-) 0.05028282412296122
#
#
# === Average network evolution ===
# Total hidden node:  27.794871794871796 (+/-) 8.437339133294934
# Number of layer:  2.923076923076923 (+/-) 0.6153846153846153
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=8, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=8, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 8
# No. of parameters : 66
# basicNet(
#   (linear): Linear(in_features=8, out_features=9, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=9, out_features=2, bias=True)
# )
# No. of inputs : 8
# No. of nodes : 9
# No. of parameters : 101
# basicNet(
#   (linear): Linear(in_features=9, out_features=18, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=18, out_features=2, bias=True)
# )
# No. of inputs : 9
# No. of nodes : 18
# No. of parameters : 218
# basicNet(
#   (linear): Linear(in_features=18, out_features=3, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=3, out_features=2, bias=True)
# )
# No. of inputs : 18
# No. of nodes : 3
# No. of parameters : 65
# Voting weight:  [0.0, 0.000999000999000999, 0.0, 0.9990009990009989]

# %%
plotPerformance(performanceHistory1[0],performanceHistory1[1],performanceHistory1[2],
                performanceHistory1[3],performanceHistory1[4],performanceHistory1[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet2, performanceHistory2, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.25)
allMetrics.append(allPerformance)
# Out:
# 100% (40 of 40) |########################| Elapsed Time: 0:00:13 ETA:  00:00:00
# === Performance result ===
# Accuracy:  67.98461538461538 (+/-) 35.030137489658514
# Testing Loss:  0.8440301871667497 (+/-) 0.8617331912739483
# Precision:  0.6666511079404467
# Recall:  0.6798461538461539
# F1 score:  0.6728440927327023
# Testing Time:  0.0067907969156901045 (+/-) 0.010065011143535243
# Training Time:  0.33246787389119464 (+/-) 0.051104559009849636
#
#
# === Average network evolution ===
# Total hidden node:  31.102564102564102 (+/-) 11.362996336049322
# Number of layer:  2.923076923076923 (+/-) 0.6153846153846153
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=7, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=7, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 7
# No. of parameters : 58
# basicNet(
#   (linear): Linear(in_features=7, out_features=10, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=10, out_features=2, bias=True)
# )
# No. of inputs : 7
# No. of nodes : 10
# No. of parameters : 102
# basicNet(
#   (linear): Linear(in_features=10, out_features=23, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=23, out_features=2, bias=True)
# )
# No. of inputs : 10
# No. of nodes : 23
# No. of parameters : 301
# basicNet(
#   (linear): Linear(in_features=23, out_features=4, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=4, out_features=2, bias=True)
# )
# No. of inputs : 23
# No. of nodes : 4
# No. of parameters : 106
# Voting weight:  [0.0, 0.000999000999000999, 0.0, 0.9990009990009989]

# %%
plotPerformance(performanceHistory2[0],performanceHistory2[1],performanceHistory2[2],
                performanceHistory2[3],performanceHistory2[4],performanceHistory2[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet3, performanceHistory3, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.25)
allMetrics.append(allPerformance)
# Out:
# 100% (40 of 40) |########################| Elapsed Time: 0:00:10 ETA:  00:00:00
# === Performance result ===
# Accuracy:  67.72307692307693 (+/-) 35.90819106282492
# Testing Loss:  0.7703589055663309 (+/-) 0.8175390644133353
# Precision:  0.6444148012127403
# Recall:  0.6772307692307692
# F1 score:  0.6588365443056852
# Testing Time:  0.003078002196091872 (+/-) 0.0010758812133791914
# Training Time:  0.273103212698912 (+/-) 0.028753911080612076
#
#
# === Average network evolution ===
# Total hidden node:  21.666666666666668 (+/-) 7.028634960055145
# Number of layer:  2.0256410256410255 (+/-) 0.42288262826847794
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=9, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=9, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 9
# No. of parameters : 74
# basicNet(
#   (linear): Linear(in_features=9, out_features=18, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=18, out_features=2, bias=True)
# )
# No. of inputs : 9
# No. of nodes : 18
# No. of parameters : 218
# basicNet(
#   (linear): Linear(in_features=18, out_features=3, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=3, out_features=2, bias=True)
# )
# No. of inputs : 18
# No. of nodes : 3
# No. of parameters : 65
# Voting weight:  [0.0, 0.000999000999000999, 0.9990009990009989]

# %%
plotPerformance(performanceHistory3[0],performanceHistory3[1],performanceHistory3[2],
                performanceHistory3[3],performanceHistory3[4],performanceHistory3[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet4, performanceHistory4, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.25)
allMetrics.append(allPerformance)
# Out:
# 100% (40 of 40) |########################| Elapsed Time: 0:00:14 ETA:  00:00:00
# === Performance result ===
# Accuracy:  68.01538461538462 (+/-) 35.03470468755772
# Testing Loss:  0.8265198063081465 (+/-) 0.8313338411299119
# Precision:  0.6668148559294309
# Recall:  0.6801538461538461
# F1 score:  0.6730698678218928
# Testing Time:  0.00541081795325646 (+/-) 0.0075504224022910245
# Training Time:  0.3605852249341133 (+/-) 0.07159868045271063
#
#
# === Average network evolution ===
# Total hidden node:  29.128205128205128 (+/-) 8.638552487895618
# Number of layer:  2.923076923076923 (+/-) 0.6153846153846153
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=11, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=11, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 11
# No. of parameters : 90
# basicNet(
#   (linear): Linear(in_features=11, out_features=9, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=9, out_features=2, bias=True)
# )
# No. of inputs : 11
# No. of nodes : 9
# No. of parameters : 128
# basicNet(
#   (linear): Linear(in_features=9, out_features=16, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=16, out_features=2, bias=True)
# )
# No. of inputs : 9
# No. of nodes : 16
# No. of parameters : 194
# basicNet(
#   (linear): Linear(in_features=16, out_features=4, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=4, out_features=2, bias=True)
# )
# No. of inputs : 16
# No. of nodes : 4
# No. of parameters : 78
# Voting weight:  [0.0, 0.000999000999000999, 0.0, 0.9990009990009989]

# %%
plotPerformance(performanceHistory4[0],performanceHistory4[1],performanceHistory4[2],
                performanceHistory4[3],performanceHistory4[4],performanceHistory4[5])

# %%
# all results

# 0: accuracy
# 1: f1_score
# 2: precision_score
# 3: recall_score
# 4: training_time
# 5: testingTime
# 6: nHiddenLayer
# 7: nHiddenNode

meanResults = np.round_(np.mean(allMetrics,0), decimals=2)
stdResults  = np.round_(np.std(allMetrics,0), decimals=2)

print('\n')
print('========== Performance creditcarddefault ==========')
print('Preq Accuracy: ', meanResults[0].item(), '(+/-)',stdResults[0].item())
print('F1 score: ', meanResults[1].item(), '(+/-)',stdResults[1].item())
print('Precision: ', meanResults[2].item(), '(+/-)',stdResults[2].item())
print('Recall: ', meanResults[3].item(), '(+/-)',stdResults[3].item())
print('Training time: ', meanResults[4].item(), '(+/-)',stdResults[4].item())
print('Testing time: ', meanResults[5].item(), '(+/-)',stdResults[5].item())

print('\n')
print('========== Network ==========')
print('Number of hidden layers: ', meanResults[6].item(), '(+/-)',stdResults[6].item())
print('Number of features: ', meanResults[7].item(), '(+/-)',stdResults[7].item())
# Out:
# ========== Performance creditcarddefault ==========
# Preq Accuracy:  67.23 (+/-) 1.09
# F1 score:  0.66 (+/-) 0.01
# Precision:  0.65 (+/-) 0.01
# Recall:  0.67 (+/-) 0.01
# Training time:  0.32 (+/-) 0.04
# Testing time:  0.0 (+/-) 0.0
#
#
# ========== Network ==========
# Number of hidden layers:  3.8 (+/-) 0.4
# Number of features:  35.4 (+/-) 6.92

# %% [markdown]
# ### Infinite Delay

# %%
print('Infinite Delay')
# Out:
# Infinite Delay

# %%
allMetrics = []

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet0, performanceHistory0, allPerformance = ADLmainId(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
#  75% (30 of 40) |##################      | Elapsed Time: 0:00:00 ETA:   0:00:00
# === Performance result ===
# Accuracy:  91.8421052631579 (+/-) 14.585223805708427
# Testing Loss:  0.45461028343752813 (+/-) 0.10540744121887483
# Precision:  0.9166143513599481
# Recall:  0.9184210526315789
# F1 score:  0.9166117206628208
# Testing Time:  0.003438397457725123 (+/-) 0.010115786697589942
# Training Time:  0.0 (+/-) 0.0
#
#
# === Average network evolution ===
# Total hidden node:  17.0 (+/-) 0.0
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=17, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=17, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 17
# No. of parameters : 138
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory0[0],performanceHistory0[1],performanceHistory0[2],
                performanceHistory0[3],performanceHistory0[4],performanceHistory0[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet1, performanceHistory1, allPerformance = ADLmainId(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
#  62% (25 of 40) |###############         | Elapsed Time: 0:00:00 ETA:   0:00:06
# === Performance result ===
# Accuracy:  92.62105263157896 (+/-) 13.514108765807386
# Testing Loss:  0.5085983409693366 (+/-) 0.07910410328440101
# Precision:  0.9257016704154889
# Recall:  0.9262105263157895
# F1 score:  0.9259257295347515
# Testing Time:  0.0018105632380435342 (+/-) 0.0007189810656263142
# Training Time:  0.0 (+/-) 0.0
#
#
# === Average network evolution ===
# Total hidden node:  19.0 (+/-) 0.0
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=19, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=19, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 19
# No. of parameters : 154
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory1[0],performanceHistory1[1],performanceHistory1[2],
                performanceHistory1[3],performanceHistory1[4],performanceHistory1[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet2, performanceHistory2, allPerformance = ADLmainId(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
#  70% (28 of 40) |################        | Elapsed Time: 0:00:00 ETA:   0:00:04
# === Performance result ===
# Accuracy:  88.10000000000001 (+/-) 19.399335311456312
# Testing Loss:  0.5769628200091814 (+/-) 0.06302654748602915
# Precision:  0.8942074266809855
# Recall:  0.881
# F1 score:  0.8849519614835393
# Testing Time:  0.001757973118832237 (+/-) 0.0006996225448291002
# Training Time:  0.0 (+/-) 0.0
#
#
# === Average network evolution ===
# Total hidden node:  12.0 (+/-) 0.0
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=12, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=12, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 12
# No. of parameters : 98
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory2[0],performanceHistory2[1],performanceHistory2[2],
                performanceHistory2[3],performanceHistory2[4],performanceHistory2[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet3, performanceHistory3, allPerformance = ADLmainId(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
#  92% (37 of 40) |######################  | Elapsed Time: 0:00:01 ETA:   0:00:00
# === Performance result ===
# Accuracy:  79.1 (+/-) 26.2142488373263
# Testing Loss:  0.4521037093118617 (+/-) 0.16292954889126382
# Precision:  0.7831187103369834
# Recall:  0.791
# F1 score:  0.7289534081122929
# Testing Time:  0.0035793216604935495 (+/-) 0.00986329806156449
# Training Time:  0.0 (+/-) 0.0
#
#
# === Average network evolution ===
# Total hidden node:  20.0 (+/-) 0.0
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=20, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=20, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 20
# No. of parameters : 162
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory3[0],performanceHistory3[1],performanceHistory3[2],
                performanceHistory3[3],performanceHistory3[4],performanceHistory3[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet4, performanceHistory4, allPerformance = ADLmainId(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
#  67% (27 of 40) |################        | Elapsed Time: 0:00:01 ETA:   0:00:00
# === Performance result ===
# Accuracy:  88.85789473684208 (+/-) 17.80502045667468
# Testing Loss:  0.49199309003980535 (+/-) 0.11224019010663568
# Precision:  0.8954949765206628
# Recall:  0.888578947368421
# F1 score:  0.8909959222604067
# Testing Time:  0.0034637576655337683 (+/-) 0.002772145482994759
# Training Time:  0.0 (+/-) 0.0
#
#
# === Average network evolution ===
# Total hidden node:  23.0 (+/-) 0.0
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=5, out_features=23, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=23, out_features=2, bias=True)
# )
# No. of inputs : 5
# No. of nodes : 23
# No. of parameters : 186
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory4[0],performanceHistory4[1],performanceHistory4[2],
                performanceHistory4[3],performanceHistory4[4],performanceHistory4[5])

# %%
# all results

# 0: accuracy
# 1: f1_score
# 2: precision_score
# 3: recall_score
# 4: training_time
# 5: testingTime
# 6: nHiddenLayer
# 7: nHiddenNode

meanResults = np.round_(np.mean(allMetrics,0), decimals=2)
stdResults  = np.round_(np.std(allMetrics,0), decimals=2)

print('\n')
print('========== Performance creditcarddefault ==========')
print('Preq Accuracy: ', meanResults[0].item(), '(+/-)',stdResults[0].item())
print('F1 score: ', meanResults[1].item(), '(+/-)',stdResults[1].item())
print('Precision: ', meanResults[2].item(), '(+/-)',stdResults[2].item())
print('Recall: ', meanResults[3].item(), '(+/-)',stdResults[3].item())
print('Training time: ', meanResults[4].item(), '(+/-)',stdResults[4].item())
print('Testing time: ', meanResults[5].item(), '(+/-)',stdResults[5].item())

print('\n')
print('========== Network ==========')
print('Number of hidden layers: ', meanResults[6].item(), '(+/-)',stdResults[6].item())
print('Number of features: ', meanResults[7].item(), '(+/-)',stdResults[7].item())
# Out:
# ========== Performance creditcarddefault ==========
# Preq Accuracy:  88.1 (+/-) 4.82
# F1 score:  0.87 (+/-) 0.07
# Precision:  0.88 (+/-) 0.05
# Recall:  0.88 (+/-) 0.05
# Training time:  0.0 (+/-) 0.0
# Testing time:  0.0 (+/-) 0.0
#
#
# ========== Network ==========
# Number of hidden layers:  1.0 (+/-) 0.0
# Number of features:  18.2 (+/-) 3.66
