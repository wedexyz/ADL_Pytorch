# %%
from ADLmainloop import ADLmain, ADLmainId
from ADLbasic import ADL
from utilsADL import dataLoader, plotPerformance
import random
import torch
import numpy as np

# %%
# random seed control
np.random.seed(0)
torch.manual_seed(0)
random.seed(0)

# %%
# load data
dataStreams = dataLoader('../dataset/creditcarddefault2.mat', batchSize = 500)
# Out:
# Number of input:  24
# Number of output:  2
# Number of batch:  60

# %%
print('All labeled')
# Out:
# All labeled

# %%
allMetrics = []

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet0, performanceHistory0, allPerformance = ADLmain(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
# 100% (60 of 60) |########################| Elapsed Time: 0:00:36 ETA:  00:00:00
# === Performance result ===
# Accuracy:  79.41694915254237 (+/-) 2.919319199853773
# Testing Loss:  0.48755703740200756 (+/-) 0.04073976462854898
# Precision:  0.7756893630188072
# Recall:  0.7941694915254237
# F1 score:  0.7326909167479804
# Testing Time:  0.002415899503028999 (+/-) 0.004680676841204345
# Training Time:  0.6116342019226592 (+/-) 0.018603670583644878
#
#
# === Average network evolution ===
# Total hidden node:  7.559322033898305 (+/-) 0.49646842426701054
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=8, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=8, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 8
# No. of parameters : 218
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory0[0],performanceHistory0[1],performanceHistory0[2],
                performanceHistory0[3],performanceHistory0[4],performanceHistory0[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet1, performanceHistory1, allPerformance = ADLmain(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
# 100% (60 of 60) |########################| Elapsed Time: 0:00:35 ETA:  00:00:00
# === Performance result ===
# Accuracy:  79.43728813559322 (+/-) 2.8280614612915134
# Testing Loss:  0.48512575788013007 (+/-) 0.04022635098044086
# Precision:  0.7771679541270987
# Recall:  0.7943728813559322
# F1 score:  0.7324057640975711
# Testing Time:  0.0028018264447228383 (+/-) 0.007243745613576345
# Training Time:  0.6022592318260064 (+/-) 0.013232788871406137
#
#
# === Average network evolution ===
# Total hidden node:  8.542372881355933 (+/-) 0.49820130361691756
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=9, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=9, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 9
# No. of parameters : 245
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory1[0],performanceHistory1[1],performanceHistory1[2],
                performanceHistory1[3],performanceHistory1[4],performanceHistory1[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet2, performanceHistory2, allPerformance = ADLmain(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
# 100% (60 of 60) |########################| Elapsed Time: 0:00:35 ETA:  00:00:00
# === Performance result ===
# Accuracy:  79.10508474576272 (+/-) 2.841187608503962
# Testing Loss:  0.49157079094547335 (+/-) 0.04032497010894298
# Precision:  0.7740560498063369
# Recall:  0.7910508474576271
# F1 score:  0.7226345557823775
# Testing Time:  0.002616288298267429 (+/-) 0.006218575644064687
# Training Time:  0.6047709432698912 (+/-) 0.014789069824755393
#
#
# === Average network evolution ===
# Total hidden node:  5.88135593220339 (+/-) 0.32336922081930364
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=6, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=6, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 6
# No. of parameters : 164
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory2[0],performanceHistory2[1],performanceHistory2[2],
                performanceHistory2[3],performanceHistory2[4],performanceHistory2[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet3, performanceHistory3, allPerformance = ADLmain(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
# 100% (60 of 60) |########################| Elapsed Time: 0:00:36 ETA:  00:00:00
# === Performance result ===
# Accuracy:  79.62033898305086 (+/-) 2.676120368009172
# Testing Loss:  0.48673865956775214 (+/-) 0.03946019310739721
# Precision:  0.7772884356038915
# Recall:  0.7962033898305084
# F1 score:  0.738833814301478
# Testing Time:  0.0018869618238028833 (+/-) 0.0005326981518543907
# Training Time:  0.6110162654165494 (+/-) 0.02336225676677746
#
#
# === Average network evolution ===
# Total hidden node:  10.694915254237289 (+/-) 0.46044331210868217
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=11, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=11, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 11
# No. of parameters : 299
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory3[0],performanceHistory3[1],performanceHistory3[2],
                performanceHistory3[3],performanceHistory3[4],performanceHistory3[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet4, performanceHistory4, allPerformance = ADLmain(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
# 100% (60 of 60) |########################| Elapsed Time: 0:00:43 ETA:  00:00:00
# === Performance result ===
# Accuracy:  79.59322033898307 (+/-) 2.4865648762206303
# Testing Loss:  0.48409492939205495 (+/-) 0.037957865160682815
# Precision:  0.7736823122390757
# Recall:  0.7959322033898305
# F1 score:  0.7411406188379286
# Testing Time:  0.002184310201871193 (+/-) 0.000777894428245328
# Training Time:  0.7374088360091388 (+/-) 0.0685992570921198
#
#
# === Average network evolution ===
# Total hidden node:  10.542372881355933 (+/-) 0.49820130361691756
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=11, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=11, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 11
# No. of parameters : 299
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory4[0],performanceHistory4[1],performanceHistory4[2],
                performanceHistory4[3],performanceHistory4[4],performanceHistory4[5])

# %%
# all results

# 0: accuracy
# 1: f1_score
# 2: precision_score
# 3: recall_score
# 4: training_time
# 5: testingTime
# 6: nHiddenLayer
# 7: nHiddenNode

meanResults = np.round_(np.mean(allMetrics,0), decimals=2)
stdResults  = np.round_(np.std(allMetrics,0), decimals=2)

print('\n')
print('========== Performance creditcarddefault ==========')
print('Preq Accuracy: ', meanResults[0].item(), '(+/-)',stdResults[0].item())
print('F1 score: ', meanResults[1].item(), '(+/-)',stdResults[1].item())
print('Precision: ', meanResults[2].item(), '(+/-)',stdResults[2].item())
print('Recall: ', meanResults[3].item(), '(+/-)',stdResults[3].item())
print('Training time: ', meanResults[4].item(), '(+/-)',stdResults[4].item())
print('Testing time: ', meanResults[5].item(), '(+/-)',stdResults[5].item())

print('\n')
print('========== Network ==========')
print('Number of hidden layers: ', meanResults[6].item(), '(+/-)',stdResults[6].item())
print('Number of features: ', meanResults[7].item(), '(+/-)',stdResults[7].item())
# Out:
# ========== Performance creditcarddefault ==========
# Preq Accuracy:  79.43 (+/-) 0.18
# F1 score:  0.73 (+/-) 0.01
# Precision:  0.78 (+/-) 0.0
# Recall:  0.79 (+/-) 0.0
# Training time:  0.63 (+/-) 0.05
# Testing time:  0.0 (+/-) 0.0
#
#
# ========== Network ==========
# Number of hidden layers:  1.0 (+/-) 0.0
# Number of features:  9.0 (+/-) 1.9

# %% [markdown]
# ### 50% labeled data

# %%
print('50% labeled')
# Out:
# 50% labeled

# %%
allMetrics = []

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet0, performanceHistory0, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.5)
allMetrics.append(allPerformance)
# Out:
# 100% (60 of 60) |########################| Elapsed Time: 0:00:22 ETA:  00:00:00
# === Performance result ===
# Accuracy:  78.83050847457629 (+/-) 2.948326398995357
# Testing Loss:  0.49461294937941985 (+/-) 0.04117888114299144
# Precision:  0.7753096470330605
# Recall:  0.7883050847457627
# F1 score:  0.712730122235057
# Testing Time:  0.00215028908293126 (+/-) 0.0005569205647039789
# Training Time:  0.38232780715166514 (+/-) 0.02009202900452281
#
#
# === Average network evolution ===
# Total hidden node:  6.016949152542373 (+/-) 0.12908090009938827
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=6, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=6, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 6
# No. of parameters : 164
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory0[0],performanceHistory0[1],performanceHistory0[2],
                performanceHistory0[3],performanceHistory0[4],performanceHistory0[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet1, performanceHistory1, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.5)
allMetrics.append(allPerformance)
# Out:
# 100% (60 of 60) |########################| Elapsed Time: 0:00:22 ETA:  00:00:00
# === Performance result ===
# Accuracy:  78.96271186440678 (+/-) 2.8547847616977964
# Testing Loss:  0.4978949968087471 (+/-) 0.04297651177922631
# Precision:  0.7733756346816727
# Recall:  0.7896271186440678
# F1 score:  0.7179959843615082
# Testing Time:  0.002930253239001258 (+/-) 0.006446872201195283
# Training Time:  0.37614336660352804 (+/-) 0.011431043633125552
#
#
# === Average network evolution ===
# Total hidden node:  8.898305084745763 (+/-) 0.3022466864428307
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=9, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=9, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 9
# No. of parameters : 245
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory1[0],performanceHistory1[1],performanceHistory1[2],
                performanceHistory1[3],performanceHistory1[4],performanceHistory1[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet2, performanceHistory2, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.5)
allMetrics.append(allPerformance)
# Out:
# 100% (60 of 60) |########################| Elapsed Time: 0:00:22 ETA:  00:00:00
# === Performance result ===
# Accuracy:  78.0440677966102 (+/-) 2.8679568813651515
# Testing Loss:  0.5090185171466762 (+/-) 0.0416322014719107
# Precision:  0.7777817297011661
# Recall:  0.7804406779661017
# F1 score:  0.686878317296202
# Testing Time:  0.0030288494239419195 (+/-) 0.006655779194027029
# Training Time:  0.38097767506615593 (+/-) 0.0176262669184586
#
#
# === Average network evolution ===
# Total hidden node:  7.47457627118644 (+/-) 0.4993532156832622
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=7, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=7, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 7
# No. of parameters : 191
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory2[0],performanceHistory2[1],performanceHistory2[2],
                performanceHistory2[3],performanceHistory2[4],performanceHistory2[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet3, performanceHistory3, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.5)
allMetrics.append(allPerformance)
# Out:
# 100% (60 of 60) |########################| Elapsed Time: 0:00:22 ETA:  00:00:00
# === Performance result ===
# Accuracy:  78.36271186440679 (+/-) 2.786279841949808
# Testing Loss:  0.49819395956346546 (+/-) 0.042258303151352254
# Precision:  0.7660330236792359
# Recall:  0.7836271186440678
# F1 score:  0.6991009840187895
# Testing Time:  0.0021723771499375165 (+/-) 0.0006239941552670955
# Training Time:  0.374457565404601 (+/-) 0.009449194337418143
#
#
# === Average network evolution ===
# Total hidden node:  5.966101694915254 (+/-) 0.18096742800053073
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=6, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=6, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 6
# No. of parameters : 164
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory3[0],performanceHistory3[1],performanceHistory3[2],
                performanceHistory3[3],performanceHistory3[4],performanceHistory3[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet4, performanceHistory4, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.5)
allMetrics.append(allPerformance)
# Out:
# 100% (60 of 60) |########################| Elapsed Time: 0:00:22 ETA:  00:00:00
# === Performance result ===
# Accuracy:  78.89830508474576 (+/-) 2.645974974927058
# Testing Loss:  0.4887200134285426 (+/-) 0.03969822709908991
# Precision:  0.7735450267570854
# Recall:  0.7889830508474577
# F1 score:  0.7156933384923209
# Testing Time:  0.002334853350105932 (+/-) 0.0007056081342932634
# Training Time:  0.3760459503885043 (+/-) 0.010680203770014609
#
#
# === Average network evolution ===
# Total hidden node:  9.915254237288135 (+/-) 0.2785029953416099
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=10, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=10, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 10
# No. of parameters : 272
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory4[0],performanceHistory4[1],performanceHistory4[2],
                performanceHistory4[3],performanceHistory4[4],performanceHistory4[5])

# %%
# all results

# 0: accuracy
# 1: f1_score
# 2: precision_score
# 3: recall_score
# 4: training_time
# 5: testingTime
# 6: nHiddenLayer
# 7: nHiddenNode

meanResults = np.round_(np.mean(allMetrics,0), decimals=2)
stdResults  = np.round_(np.std(allMetrics,0), decimals=2)

print('\n')
print('========== Performance creditcarddefault ==========')
print('Preq Accuracy: ', meanResults[0].item(), '(+/-)',stdResults[0].item())
print('F1 score: ', meanResults[1].item(), '(+/-)',stdResults[1].item())
print('Precision: ', meanResults[2].item(), '(+/-)',stdResults[2].item())
print('Recall: ', meanResults[3].item(), '(+/-)',stdResults[3].item())
print('Training time: ', meanResults[4].item(), '(+/-)',stdResults[4].item())
print('Testing time: ', meanResults[5].item(), '(+/-)',stdResults[5].item())

print('\n')
print('========== Network ==========')
print('Number of hidden layers: ', meanResults[6].item(), '(+/-)',stdResults[6].item())
print('Number of features: ', meanResults[7].item(), '(+/-)',stdResults[7].item())
# Out:
# ========== Performance creditcarddefault ==========
# Preq Accuracy:  78.62 (+/-) 0.36
# F1 score:  0.71 (+/-) 0.01
# Precision:  0.77 (+/-) 0.0
# Recall:  0.79 (+/-) 0.0
# Training time:  0.38 (+/-) 0.0
# Testing time:  0.0 (+/-) 0.0
#
#
# ========== Network ==========
# Number of hidden layers:  1.0 (+/-) 0.0
# Number of features:  7.6 (+/-) 1.62

# %% [markdown]
# ### 25% Labeled Data

# %%
print('25% labeled')
# Out:
# 25% labeled

# %%
allMetrics = []

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet0, performanceHistory0, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.25)
allMetrics.append(allPerformance)
# Out:
# 100% (60 of 60) |########################| Elapsed Time: 0:00:11 ETA:  00:00:00
# === Performance result ===
# Accuracy:  77.9627118644068 (+/-) 2.8196584902650255
# Testing Loss:  0.5119317325495057 (+/-) 0.03896882344682943
# Precision:  0.7868658904344386
# Recall:  0.7796271186440678
# F1 score:  0.6841496226599842
# Testing Time:  0.0017881393432617188 (+/-) 0.0007510242110440656
# Training Time:  0.19816371950052553 (+/-) 0.008002807931866331
#
#
# === Average network evolution ===
# Total hidden node:  6.915254237288136 (+/-) 0.3338595865015629
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=7, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=7, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 7
# No. of parameters : 191
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory0[0],performanceHistory0[1],performanceHistory0[2],
                performanceHistory0[3],performanceHistory0[4],performanceHistory0[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet1, performanceHistory1, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.25)
allMetrics.append(allPerformance)
# Out:
# 100% (60 of 60) |########################| Elapsed Time: 0:00:13 ETA:  00:00:00
# === Performance result ===
# Accuracy:  78.39999999999999 (+/-) 2.5739239976663484
# Testing Loss:  0.49973840834730765 (+/-) 0.03869122553309028
# Precision:  0.7649284507695636
# Recall:  0.784
# F1 score:  0.7007627072053836
# Testing Time:  0.0031417143546928795 (+/-) 0.008931633739295867
# Training Time:  0.2158358339535988 (+/-) 0.0162206890130608
#
#
# === Average network evolution ===
# Total hidden node:  8.0 (+/-) 0.0
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=8, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=8, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 8
# No. of parameters : 218
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory1[0],performanceHistory1[1],performanceHistory1[2],
                performanceHistory1[3],performanceHistory1[4],performanceHistory1[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet2, performanceHistory2, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.25)
allMetrics.append(allPerformance)
# Out:
# 100% (60 of 60) |########################| Elapsed Time: 0:00:13 ETA:  00:00:00
# === Performance result ===
# Accuracy:  78.18305084745764 (+/-) 2.7224834464250844
# Testing Loss:  0.5103884359537545 (+/-) 0.039759660863337876
# Precision:  0.774622374731709
# Recall:  0.7818305084745762
# F1 score:  0.6915631150912832
# Testing Time:  0.002958152253749007 (+/-) 0.0067554425679066795
# Training Time:  0.2193795947705285 (+/-) 0.032284920016064936
#
#
# === Average network evolution ===
# Total hidden node:  7.898305084745763 (+/-) 0.35390869521730683
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=8, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=8, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 8
# No. of parameters : 218
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory2[0],performanceHistory2[1],performanceHistory2[2],
                performanceHistory2[3],performanceHistory2[4],performanceHistory2[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet3, performanceHistory3, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.25)
allMetrics.append(allPerformance)
# Out:
# 100% (60 of 60) |########################| Elapsed Time: 0:00:12 ETA:  00:00:00
# === Performance result ===
# Accuracy:  78.13898305084744 (+/-) 2.6472254070337367
# Testing Loss:  0.5089111151331562 (+/-) 0.04273084292539326
# Precision:  0.7545519363212778
# Recall:  0.7813898305084745
# F1 score:  0.6926933747691769
# Testing Time:  0.001958960193698689 (+/-) 0.0010710995278204803
# Training Time:  0.20686279313038972 (+/-) 0.010634434219405983
#
#
# === Average network evolution ===
# Total hidden node:  7.576271186440678 (+/-) 0.5273338707153915
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=8, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=8, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 8
# No. of parameters : 218
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory3[0],performanceHistory3[1],performanceHistory3[2],
                performanceHistory3[3],performanceHistory3[4],performanceHistory3[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet4, performanceHistory4, allPerformance = ADLmain(ADLnet,dataStreams,labeled = False, nLabeled = 0.25)
allMetrics.append(allPerformance)
# Out:
# 100% (60 of 60) |########################| Elapsed Time: 0:00:12 ETA:  00:00:00
# === Performance result ===
# Accuracy:  78.08474576271186 (+/-) 2.7654535631501167
# Testing Loss:  0.5039280264054314 (+/-) 0.03783505415713043
# Precision:  0.7741201758817735
# Recall:  0.7808474576271186
# F1 score:  0.6883822637672568
# Testing Time:  0.002204838445631124 (+/-) 0.001060149011514266
# Training Time:  0.19968664848198325 (+/-) 0.014195909808951648
#
#
# === Average network evolution ===
# Total hidden node:  8.711864406779661 (+/-) 0.48888830853749
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=9, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=9, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 9
# No. of parameters : 245
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory4[0],performanceHistory4[1],performanceHistory4[2],
                performanceHistory4[3],performanceHistory4[4],performanceHistory4[5])

# %%
# all results

# 0: accuracy
# 1: f1_score
# 2: precision_score
# 3: recall_score
# 4: training_time
# 5: testingTime
# 6: nHiddenLayer
# 7: nHiddenNode

meanResults = np.round_(np.mean(allMetrics,0), decimals=2)
stdResults  = np.round_(np.std(allMetrics,0), decimals=2)

print('\n')
print('========== Performance creditcarddefault ==========')
print('Preq Accuracy: ', meanResults[0].item(), '(+/-)',stdResults[0].item())
print('F1 score: ', meanResults[1].item(), '(+/-)',stdResults[1].item())
print('Precision: ', meanResults[2].item(), '(+/-)',stdResults[2].item())
print('Recall: ', meanResults[3].item(), '(+/-)',stdResults[3].item())
print('Training time: ', meanResults[4].item(), '(+/-)',stdResults[4].item())
print('Testing time: ', meanResults[5].item(), '(+/-)',stdResults[5].item())

print('\n')
print('========== Network ==========')
print('Number of hidden layers: ', meanResults[6].item(), '(+/-)',stdResults[6].item())
print('Number of features: ', meanResults[7].item(), '(+/-)',stdResults[7].item())
# Out:
# ========== Performance creditcarddefault ==========
# Preq Accuracy:  78.15 (+/-) 0.14
# F1 score:  0.69 (+/-) 0.01
# Precision:  0.77 (+/-) 0.01
# Recall:  0.78 (+/-) 0.0
# Training time:  0.21 (+/-) 0.01
# Testing time:  0.0 (+/-) 0.0
#
#
# ========== Network ==========
# Number of hidden layers:  1.0 (+/-) 0.0
# Number of features:  8.0 (+/-) 0.63

# %% [markdown]
# ### Infinite Delay

# %%
print('Infinite Delay')
# Out:
# Infinite Delay

# %%
allMetrics = []

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet0, performanceHistory0, allPerformance = ADLmainId(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
#  98% (59 of 60) |####################### | Elapsed Time: 0:00:00 ETA:   0:00:00C:\Users\SCSE\AppData\Local\Continuum\miniconda3\envs\stmicro\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# === Performance result ===
# Accuracy:  77.8551724137931 (+/-) 2.889646942626747
# Testing Loss:  0.5298441047298497 (+/-) 0.03682144477224927
# Precision:  0.6061427871581452
# Recall:  0.7785517241379311
# F1 score:  0.6816138984678044
# Testing Time:  0.0013070188719650794 (+/-) 0.0006724873172075884
# Training Time:  0.0 (+/-) 0.0
#
#
# === Average network evolution ===
# Total hidden node:  7.0 (+/-) 0.0
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=7, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=7, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 7
# No. of parameters : 191
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory0[0],performanceHistory0[1],performanceHistory0[2],
                performanceHistory0[3],performanceHistory0[4],performanceHistory0[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet1, performanceHistory1, allPerformance = ADLmainId(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
#  81% (49 of 60) |###################     | Elapsed Time: 0:00:00 ETA:   0:00:00C:\Users\SCSE\AppData\Local\Continuum\miniconda3\envs\stmicro\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# === Performance result ===
# Accuracy:  77.8551724137931 (+/-) 2.889646942626747
# Testing Loss:  0.5454619290499851 (+/-) 0.051113393075722824
# Precision:  0.6061427871581452
# Recall:  0.7785517241379311
# F1 score:  0.6816138984678044
# Testing Time:  0.002338984916950094 (+/-) 0.006471644817475855
# Training Time:  0.0 (+/-) 0.0
#
#
# === Average network evolution ===
# Total hidden node:  9.0 (+/-) 0.0
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=9, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=9, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 9
# No. of parameters : 245
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory1[0],performanceHistory1[1],performanceHistory1[2],
                performanceHistory1[3],performanceHistory1[4],performanceHistory1[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet2, performanceHistory2, allPerformance = ADLmainId(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
#  81% (49 of 60) |###################     | Elapsed Time: 0:00:00 ETA:   0:00:00C:\Users\SCSE\AppData\Local\Continuum\miniconda3\envs\stmicro\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# === Performance result ===
# Accuracy:  77.8551724137931 (+/-) 2.889646942626747
# Testing Loss:  0.5242812623237741 (+/-) 0.03540778697918871
# Precision:  0.6061427871581452
# Recall:  0.7785517241379311
# F1 score:  0.6816138984678044
# Testing Time:  0.0027256587456012593 (+/-) 0.00750983867309018
# Training Time:  0.0 (+/-) 0.0
#
#
# === Average network evolution ===
# Total hidden node:  5.0 (+/-) 0.0
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=5, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=5, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 5
# No. of parameters : 137
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory2[0],performanceHistory2[1],performanceHistory2[2],
                performanceHistory2[3],performanceHistory2[4],performanceHistory2[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet3, performanceHistory3, allPerformance = ADLmainId(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
#  76% (46 of 60) |##################      | Elapsed Time: 0:00:00 ETA:   0:00:00C:\Users\SCSE\AppData\Local\Continuum\miniconda3\envs\stmicro\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# === Performance result ===
# Accuracy:  77.8551724137931 (+/-) 2.889646942626747
# Testing Loss:  0.522946532944153 (+/-) 0.04129066532358727
# Precision:  0.6061427871581452
# Recall:  0.7785517241379311
# F1 score:  0.6816138984678044
# Testing Time:  0.00192841990240689 (+/-) 0.0006663854214555403
# Training Time:  0.0 (+/-) 0.0
#
#
# === Average network evolution ===
# Total hidden node:  15.0 (+/-) 0.0
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=15, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=15, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 15
# No. of parameters : 407
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory3[0],performanceHistory3[1],performanceHistory3[2],
                performanceHistory3[3],performanceHistory3[4],performanceHistory3[5])

# %%
# initialization
ADLnet = ADL(dataStreams.nInput,dataStreams.nOutput)

# %%
ADLnet4, performanceHistory4, allPerformance = ADLmainId(ADLnet,dataStreams)
allMetrics.append(allPerformance)
# Out:
#  85% (51 of 60) |####################    | Elapsed Time: 0:00:00 ETA:   0:00:00C:\Users\SCSE\AppData\Local\Continuum\miniconda3\envs\stmicro\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# === Performance result ===
# Accuracy:  77.8551724137931 (+/-) 2.889646942626747
# Testing Loss:  0.537564495000346 (+/-) 0.027670558661595485
# Precision:  0.6061427871581452
# Recall:  0.7785517241379311
# F1 score:  0.6816138984678044
# Testing Time:  0.0017378987937137999 (+/-) 0.0008614628336203117
# Training Time:  0.0 (+/-) 0.0
#
#
# === Average network evolution ===
# Total hidden node:  9.0 (+/-) 0.0
# Number of layer:  1.0 (+/-) 0.0
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=24, out_features=9, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=9, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of nodes : 9
# No. of parameters : 245
# Voting weight:  [1.0]

# %%
plotPerformance(performanceHistory4[0],performanceHistory4[1],performanceHistory4[2],
                performanceHistory4[3],performanceHistory4[4],performanceHistory4[5])

# %%
# all results

# 0: accuracy
# 1: f1_score
# 2: precision_score
# 3: recall_score
# 4: training_time
# 5: testingTime
# 6: nHiddenLayer
# 7: nHiddenNode

meanResults = np.round_(np.mean(allMetrics,0), decimals=2)
stdResults  = np.round_(np.std(allMetrics,0), decimals=2)

print('\n')
print('========== Performance creditcarddefault ==========')
print('Preq Accuracy: ', meanResults[0].item(), '(+/-)',stdResults[0].item())
print('F1 score: ', meanResults[1].item(), '(+/-)',stdResults[1].item())
print('Precision: ', meanResults[2].item(), '(+/-)',stdResults[2].item())
print('Recall: ', meanResults[3].item(), '(+/-)',stdResults[3].item())
print('Training time: ', meanResults[4].item(), '(+/-)',stdResults[4].item())
print('Testing time: ', meanResults[5].item(), '(+/-)',stdResults[5].item())

print('\n')
print('========== Network ==========')
print('Number of hidden layers: ', meanResults[6].item(), '(+/-)',stdResults[6].item())
print('Number of features: ', meanResults[7].item(), '(+/-)',stdResults[7].item())
# Out:
# ========== Performance creditcarddefault ==========
# Preq Accuracy:  77.86 (+/-) 0.0
# F1 score:  0.68 (+/-) 0.0
# Precision:  0.61 (+/-) 0.0
# Recall:  0.78 (+/-) 0.0
# Training time:  0.0 (+/-) 0.0
# Testing time:  0.0 (+/-) 0.0
#
#
# ========== Network ==========
# Number of hidden layers:  1.0 (+/-) 0.0
# Number of features:  9.0 (+/-) 3.35
