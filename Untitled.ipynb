# %%
# %run ADL_covtype.ipynb  # 500
# Out:
# Number of input:  54
# Number of output:  7
# Number of batch:  1162
# All labeled
# 100% (1162 of 1162) |####################| Elapsed Time: 1:37:01 ETA:  00:00:00
# === Performance result ===
# Accuracy:  68.62342807924203 (+/-) 13.708522367200196
# Testing Loss:  0.7492453498472231 (+/-) 0.30371059303824177
# Precision:  0.6845334579659612
# Recall:  0.6862342807924203
# F1 score:  0.6744047107878377
# Testing Time:  0.14601752924364667 (+/-) 0.11911297801432097
# Training Time:  4.862639973021909 (+/-) 10.020636442765726
#
#
# === Average network evolution ===
# Total hidden node:  914.8044788975021 (+/-) 697.1096391083216
# Number of layer:  70.83031869078381 (+/-) 55.7461297697735
#
#
# === Final network structure ===
# basicNet(
#   (linear): Linear(in_features=54, out_features=38, bias=True)
#   (activation): Sigmoid()
#   (linearOutput): Linear(in_features=38, out_features=7, bias=True)
# )
# No. of inputs : 54
# No. of nodes : 38
# No. of parameters : 2363
# basicNet(
# ...

# %%
# %run ../2_NADINE/NADINE_classification_covtype.ipynb
# Out:
# Number of input:  54
# Number of output:  7
# Number of batch:  581
# All Data
#   0% (3 of 581) |                        | Elapsed Time: 0:00:03 ETA:   0:12:22
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# D:\thesis\2_NADINE\NADINE_classification_covtype.ipynb in <module>
# ----> 1 NADINEnet0, performanceHistory0 = NADINEmain(NADINEnet,dataStreams)
#
# D:\thesis\2_NADINE\NADINEmainloop.py in NADINEmain(NADINEnet, dataStreams, trainingBatchSize, noOfEpoch, labeled, nLabeled)
#      80         # training
#      81         if NADINEnet.driftStatus == 0 or NADINEnet.driftStatus == 2:  # only train if it is stable or drift
# ---> 82             NADINEnet.training(batchSize = trainingBatchSize, epoch = noOfEpoch)
#      83
#      84         end_train = time.time()
#
# D:\thesis\2_NADINE\NADINEbasic.py in training(self, device, batchSize, epoch)
# ...

# %%
# %run ../3_DEVDAN/DEVDAN_covtype.ipynb
# Out:
# Number of input:  54
# Number of output:  7
# Number of batch:  581
# All Data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# D:\thesis\3_DEVDAN\DEVDAN_covtype.ipynb in <module>
# ----> 1 DevdanNet0, performanceHistory0 = DEVDANmain(DevdanNet,dataStreams)
#
# D:\thesis\3_DEVDAN\DEVDANmainloop.py in DEVDANmain(DEVDANnet, dataStreams, trainingBatchSize, noOfEpoch, labeled, nLabeled)
#      66
#      67         # discriminative training
# ---> 68         DEVDANnet.discriminativeTraining(batchSize = trainingBatchSize, epoch = noOfEpoch)
#      69
#      70         # calculate network evolution discriminative
#
# D:\thesis\3_DEVDAN\DEVDANbasic.py in discriminativeTraining(self, device, batchSize, epoch)
#     643
#     644                 # forward pass
# --> 645                 self.feedforwardTrainDiscriminative(minibatch_xTrain)
# ...

# %%
# %run ADL_covtype.ipynb  # 1000
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# D:\thesis\1_ADL\ADL_covtype.ipynb in <module>
#       1 # load data
# ----> 2 dataStreams = dataLoader('../dataset/covtype2.mat', batchSize = 1000)
#
# D:\thesis\1_ADL\utilsADL.py in __init__(self, fileName, batchSize)
#      61         self.fileName  = fileName
#      62         self.batchSize = batchSize
# ---> 63         self.loadDataFromMatFile()
#      64
#      65     def loadDataFromMatFile(self):
#
# D:\thesis\1_ADL\utilsADL.py in loadDataFromMatFile(self)
#      64
#      65     def loadDataFromMatFile(self):
# ---> 66         data1          = scipy.io.loadmat(self.fileName)  # change your folder
#      67         data           = data1.get('data')
#      68         data           = torch.from_numpy(data)
#
# ...
